# %%
import pandas as pd

# %%
df=pd.read_csv("/content/spotify_millsongdata.csv")

# %%
df.head(10)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
# 5   ABBA     Burning My Bridges    /a/abba/burning+my+bridges_20003011.html
# 6   ABBA              Cassandra             /a/abba/cassandra_20002811.html
# 7   ABBA             Chiquitita            /a/abba/chiquitita_20002978.html
# 8   ABBA            Crazy World           /a/abba/crazy+world_20003013.html
# 9   ABBA        Crying Over You       /a/abba/crying+over+you_20177611.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# ...

# %%
df.tail(10)
# Out:
#              artist           song  \
# 57640     Zebrahead      The Setup
# 57641  Ziggy Marley   Freedom Road
# 57642  Ziggy Marley         Friend
# 57643  Ziggy Marley             G7
# 57644  Ziggy Marley     Generation
# 57645  Ziggy Marley  Good Old Days
# 57646  Ziggy Marley  Hand To Mouth
# 57647          Zwan   Come With Me
# 57648          Zwan         Desire
# 57649          Zwan      Heartsong
#
#                                               link  \
# 57640         /z/zebrahead/the+setup_10198494.html
# 57641   /z/ziggy+marley/freedom+road_20531174.html
# 57642         /z/ziggy+marley/friend_20673508.html
# 57643             /z/ziggy+marley/g7_20531173.html
# 57644     /z/ziggy+marley/generation_20531171.html
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
# ...

# %%
df.shape
# Out:
# (57650, 4)

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df=df.drop('link',axis = 1).reset_index(drop=True)

# %%
df.head(10)
# Out:
#   artist                   song  \
# 0   ABBA  Ahe's My Kind Of Girl
# 1   ABBA       Andante, Andante
# 2   ABBA         As Good As New
# 3   ABBA                   Bang
# 4   ABBA       Bang-A-Boomerang
# 5   ABBA     Burning My Bridges
# 6   ABBA              Cassandra
# 7   ABBA             Chiquitita
# 8   ABBA            Crazy World
# 9   ABBA        Crying Over You
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...
# 5  Well, you hoot and you holler and you make me ...
# 6  Down in the street they're all singing and sho...
# 7  Chiquitita, tell me what's wrong  \r\nYou're e...
# 8  I was out with the morning sun  \r\nCouldn't s...
# 9  I'm waitin' for you baby  \r\nI'm sitting all ...

# %%
df['text'][0]
# Out:
# "Look at her face, it's a wonderful face  \r\nAnd it means something special to me  \r\nLook at the way that she smiles when she sees me  \r\nHow lucky can one fellow be?  \r\n  \r\nShe's just my kind of girl, she makes me feel fine  \r\nWho could ever believe that she could be mine?  \r\nShe's just my kind of girl, without her I'm blue  \r\nAnd if she ever leaves me what could I do, what could I do?  \r\n  \r\nAnd when we go for a walk in the park  \r\nAnd she holds me and squeezes my hand  \r\nWe'll go on walking for hours and talking  \r\nAbout all the things that we plan  \r\n  \r\nShe's just my kind of girl, she makes me feel fine  \r\nWho could ever believe that she could be mine?  \r\nShe's just my kind of girl, without her I'm blue  \r\nAnd if she ever leaves me what could I do, what could I do?\r\n\r\n"

# %%
df=df.sample(10000)

# %%
df.shape
# Out:
# (10000, 3)

# %% [markdown]
# Text preprocessing or Text Cleaing

# %%
df['text']=df['text'].str.lower()

# %%
df['text']=df['text'].replace(r'[a-zA-Z0-9]', ' ', regex=True)

# %%
df['text'] = df['text'].replace(r'\n', ' ', regex=True)

# %%
df.head(10)
# Out:
#                          artist              song  \
# 16865  Rage Against The Machine    Zapata's Blood
# 51699                    Slayer      Mind Control
# 9121               James Taylor     Not Fade Away
# 32924               Frank Zappa              Andy
# 14493          Notorious B.I.G.     Can't You See
# 13520             Natalie Grant    There Is A God
# 14974             One Direction        No Control
# 56698         Within Temptation          Overcome
# 23231                   Alabama  Starting Tonight
# 23767                Alphaville  Dangerous Places
#
#                                                     text
# 16865                     \r     '                 \r...
# 51699                                       \r       ...
# 9121                          '          ,  \r    '  ...
# 32924              (      ,       )  \r             (...
# 14493                                                ...
# 13520                             \r                 ...
# ...

# %%
pip install nltk

# %%
import nltk
from nltk.stem.porter import PorterStemmer

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
stemmer=PorterStemmer()

# %%
def token(txt):
  token=nltk.word_tokenize(txt)
  a=[stemmer.stem(w) for w in token]
  return " ".join(a)

# %%
token("you are beautiful, beauty")
# Out:
# 'you are beauti , beauti'

# %%
df['text'].apply(lambda x: token(x))
# Out:
# 16865    ' ' ' ' ' ' , ' ' ' ' , ' , ' ' , ' , ' , , , ...
# 51699                                          , , , , - ,
# 9121                       ' , ' , , . , ! , , , ' . , , !
# 32924    ( , ) ( , , ) ( , , ) ( ) ( ) ( , , ) ' ( ) ``...
# 14493    , ' ' ? ( , , ' ) ' ? ' ' , , , ' ' : ' , - ' ...
#                                ...
# 1982     [ ] ' ' ' , [ - ] ' [ ] ' ' , ' , ' ' , ' ' [ ...
# 4927                 - ' ' ' ' , ' ' , , , ' ' , ' ' , , ,
# 4449                     , ' , ' ' ' ' , ' ' ' ' ' ' ' , '
# 15920                                    ' ' ' ' ' ' ' ' '
# 10721    [ ] ' [ ] ' ' [ ] ' ( ) [ ] ' ' [ ] ' ' ( ) ( ...
# Name: text, Length: 10000, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity # Correct the module name here

# %%
tfid=TfidfVectorizer(analyzer='word',stop_words='english')

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# Sample DataFrame (replace with your actual data)
df = pd.DataFrame({'text': ["This is a sample sentence.", "Another sentence with some words."]})

# Custom tokenizer to handle tokenization if needed
def custom_tokenizer(text):
    # Implement your tokenization logic here, e.g., using nltk.word_tokenize
    return text.split()  # Simple split for demonstration

# Initialize TfidfVectorizer with custom tokenizer and adjusted stop words
tfid = TfidfVectorizer(analyzer='word', tokenizer=custom_tokenizer, stop_words=['the', 'a', 'an'])  # Reduce stop words

# Fit and transform the text data
matrix = tfid.fit_transform(df['text'])

print(matrix)
# Out:
#   (0, 4)	0.5
#   (0, 2)	0.5
#   (0, 1)	0.5
#   (0, 6)	0.5
#   (1, 8)	0.447213595499958
#   (1, 5)	0.447213595499958
#   (1, 7)	0.447213595499958
#   (1, 3)	0.447213595499958
#   (1, 0)	0.447213595499958
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
similar=cosine_similarity(matrix)

# %%
similar[0]
# Out:
# array([1., 0.])

# %%
# Check if the text exists in the DataFrame before accessing the index
if 'Girls For All Sesons' in df['text'].values:
    index = df[df['text']=='Girls For All Sesons'].index[0]
    print(index)
else:
    print("Text not found in DataFrame.")
# Out:
# Text not found in DataFrame.

# %% [markdown]
# Recommender Function

# %%
def recommender(song_name, df):  # Add df as a parameter
    # Indent the code within the function body
    if 'song' not in df.columns:
        print("Error: 'song' column not found in DataFrame.")
        return []  # Return an empty list if 'song' column is missing

    idx = df[df['song'] == song_name].index[0]

    distance = sorted(list(enumerate(similer[idx])), reverse=True, key=lambda x: x[1])

    song = []

    for s_id in distance[1:21]:
        # You'll likely want to add code here to append recommended songs to the 'song' list
        pass

    return song

# Call the function, passing the DataFrame as an argument
recommender("Can't You See", df)
# Out:
# Error: 'song' column not found in DataFrame.
# []

# %%
import pickle
pickle.dump(similar,open('similar.pkl','wb'))
pickle.dump(df,open('df','wb'))

# %%
pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 55.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 68.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...

# %%
pip install spotipy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.6/255.6 kB 6.6 MB/s eta 0:00:00
# ...
